# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time, names, random, undetected_chromedriver as uc

class FaceBookAccountCreator:
    def __init__(self):
        self.creator = "Ahmed Mujtaba"
    
    def create_driver(self):
        self.driver = uc.Chrome()
        self.driver.get("https://m.facebook.com/reg/?is_two_steps_login=0&cid=103&refsrc=deprecated&soft=hjk")
        self.wait = WebDriverWait(self.driver, 15)
    
    def sleep(self, time_to_wait : int):
        time.sleep(time_to_wait) 
    
    def first_page(self):
        self.next_button = self.wait.until(EC.presence_of_element_located((By.XPATH, "(//button[@value='Next'])[1]")))
        try:
            self.next_button.click()
        except:pass
        self.firstname = self.wait.until(EC.presence_of_element_located((By.XPATH, "//input[@name='firstname']")))
        self.firstname.send_keys(names.get_first_name())
        self.lastname = self.wait.until(EC.presence_of_element_located((By.XPATH, "//input[@name='lastname']")))
        self.lastname.send_keys(names.get_last_name())
        self.next_button.click()
    
    def second_page(self):
        self.day = self.wait.until(EC.presence_of_element_located((By.ID,"day")))
        self.day.send_keys(random.randint(1,28))
        random_month: int = random.randint(1,12)
        self.wait.until(EC.presence_of_element_located((By.XPATH,f"//select[@name='birthday_month']//option[@value='{random_month}']"))).click()
        self.wait.until(EC.presence_of_element_located((By.ID,'year'))).send_keys(1972,2003)
        self.next_button.click()
    
    def clicking_email_address_button(self):
        self.wait.until(EC.presence_of_element_located((By.XPATH,'//a[@data-sigil="switch_phone_to_email"]'))).click()

    def email_address(self):
        self.wait.until(EC.presence_of_element_located((By.ID,'contactpoint_step_input'))).send_keys('41unknown@jcnorris.com')
        self.next_button.click()
    
    def select_gender(self):
        self.wait.until(EC.presence_of_element_located((By.ID,'Male'))).click()
        self.next_button.click()
    
    def password(self):
        random_password = f"{random.randint(1,9999)}@{random.choice(['a','b','c','d','e','f'])}!ahmed"
        self.wait.until(EC.presence_of_element_located((By.ID,'password_step_input'))).send_keys(random_password)
        self.sign_up_button = self.wait.until(EC.presence_of_element_located((By.XPATH, "(//button[@value='Sign Up'])[1]")))
        self.sign_up_button.click()


facebook = FaceBookAccountCreator()
facebook.create_driver()
facebook.sleep(2)
facebook.first_page()
facebook.sleep(2)
facebook.second_page()
facebook.sleep(2)
facebook.clicking_email_address_button()
facebook.sleep(2)
facebook.email_address()
facebook.sleep(2)
facebook.select_gender()
facebook.sleep(2)
facebook.password()
facebook.sleep(2)
